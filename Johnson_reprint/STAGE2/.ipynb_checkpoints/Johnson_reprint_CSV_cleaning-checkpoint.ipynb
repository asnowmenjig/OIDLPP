# %%
## PROCESS NOTES ##


infile_csv (naming format: Letter_*_counts_V5.csv, content format: name, string) (open as 'r')


new outfiles:
    
positive_csv (naming format: Letter_*_positives.csv, content format: name, string) (open as 'w')
review_csv (naming format: Letter_*_review.csv, content format: name, string) (open as 'w')



individual function for each author

open CSV infile:
    for row in the csv file:
        evaluate what author name is in the 'name' column
        apply appropriate function based on name
    
    else: (no more rows left):
        redefine CSV infile
        redefine CSV positive
        redefine CSV review
        go to next letter CSV
    
function:
    use regex? or hard code?


import re
shakespeare function:         [\s]sha[okfli][^l][^n]
    for row:
        if re.match('shak[^a-z]', row[1]):            #'shak ', 'shak.', 'shak's'
            write row to positive_csv
        elif re.match('shak[es][sp][peh]', row[1]):      #'shakespeare', 'shakspeare', 'shakesh', 'shakesp.'
            write row to positive_csv
        elif re.match('shakof', row[1]):                #'shakoff--'
            write row to positive_csv
        else:
            write row to review_csv
            
            
spenser function:            [\s]sp[eo\s][nos]s[oe\s]
    for row:
        if re.match('[\s]spens', row[1]):          #'spensor', 'spensor's', 'spens.', 'spens ', 
            write row to positive_csv
        else:
            write row to review_csv
            
            
dryden function:                       ry[^i^\s^n]   dry[\s][dl][eo][hnr]
    for row:
        if re.match('[^a-z]dryd', row[1]):
            write row to positive_csv
        else:
            write row to review_csv

# %%
#important stuff

import csv
import re
import glob

csv_list = glob.glob('Letter_*_test.csv')
alpha_sect = 65

# %%
#defining author functions
#
def shakespeare_confirmation(x_line):
    if re.findall('shak[^a-z]', x_line):
        with open("Letter_" + str(chr(alpha_sect)) + "_positive.csv", 'a', newline = '', encoding="UTF-8") as positive_csv:
            positive_filewriter = csv.writer(positive_csv, delimiter=',')
            row = ["Shakespeare", x_line]
            positive_filewriter.writerow(row)
            print("found shakespeare")
    elif re.findall('shak[es][sp][peh]', x_line):
        with open("Letter_" + str(chr(alpha_sect)) + "_positive.csv", 'a', newline = '', encoding="UTF-8") as positive_csv:
            positive_filewriter = csv.writer(positive_csv, delimiter=',')
            row = ["Shakespeare", x_line]
            positive_filewriter.writerow(row)
            print("found shakespeare")
    elif re.findall('shakof', x_line):
        with open("Letter_" + str(chr(alpha_sect)) + "_positive.csv", 'a', newline = '', encoding="UTF-8") as positive_csv:
            positive_filewriter = csv.writer(positive_csv, delimiter=',')
            row = ["Shakespeare", x_line]
            positive_filewriter.writerow(row)
            print("found shakespeare")
    else:
        with open("Letter_" + str(chr(alpha_sect)) + "_review.csv", 'a', newline = '', encoding="UTF-8") as review_csv:
            review_filewriter = csv.writer(review_csv, delimiter=',')
            row = ["Shakespeare", x_line]
            review_filewriter.writerow(row)
            print("found fake shakespeare")
#
def spenser_confirmation(x_line):
    if re.findall('[\s]spens', x_line):
        with open("Letter_" + str(chr(alpha_sect)) + "_positive.csv", 'a', newline = '', encoding="UTF-8") as positive_csv:
            positive_filewriter = csv.writer(positive_csv, delimiter=',')
            row = ["Spenser", x_line]
            positive_filewriter.writerow(row)
            print("found spenser")
    else:
        with open("Letter_" + str(chr(alpha_sect)) + "_review.csv", 'a', newline = '', encoding="UTF-8") as review_csv:
            review_filewriter = csv.writer(review_csv, delimiter=',')
            row = ["Spenser", x_line]
            review_filewriter.writerow(row)
            print("found fake spenser")
#
def dryden_confirmation(x_line):
    if re.findall('[^a-z]dryd', x_line):
        with open("Letter_" + str(chr(alpha_sect)) + "_positive.csv", 'a', newline = '', encoding="UTF-8") as positive_csv:
            positive_filewriter = csv.writer(positive_csv, delimiter=',')
            row = ["Dryden", x_line]
            positive_filewriter.writerow(row)
            print('found dryden')
    else:
        with open("Letter_" + str(chr(alpha_sect)) + "_review.csv", 'a', newline = '', encoding="UTF-8") as review_csv:
            review_filewriter = csv.writer(review_csv, delimiter=',')
            row = ["Dryden", x_line]
            review_filewriter.writerow(row)
            print('found fake dryden')
#

# %%
index_value = 0
#
for csv_list[index_value] in csv_list:
    with open(csv_list[index_value], 'r') as infile_csv:
        filereader = csv.reader(infile_csv, delimiter=',')
#
        for row in filereader:
            print(row)
#
            if "csv_end" in row[0]:
                if alpha_sect == 75 or alpha_sect == 85:
                    alpha_sect = alpha_sect +2
                else:
                    alpha_sect = alpha_sect + 1

                index_value = index_value + 1
#
            else:
                print(row[0])
                if "Shakespeare" in row[0]:
                    shakespeare_confirmation(row[1])
                elif "Spenser" in row[0]:
                    spenser_confirmation(row[1])
                elif "Dryden" in row[0]:
                    dryden_confirmation(row[1])
#
